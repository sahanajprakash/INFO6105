# %% [markdown]
# # Assignment 2 - Tesla

# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas_datareader import DataReader
from datetime import datetime
import scipy.stats as ss
import yfinance as yf

start_date = datetime(2020,1,31)
end_date = datetime(2024,8,31)

# %%
stock = yf.download('TSLA',start= start_date, end = end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Garch Model

# %%
def garch(param, *args):
    # Initialize Params
    mu = param[0]
    omega = param[1]
    alpha = param[2]
    beta = param[3]
    GARCH_Dens, sigma2, F, v = {}, {}, {}, {} 
    # intialize values 
    sigma2[0] = np.var(Y)
    Likelihood = 0
    for t in range(1, T):
        sigma2[t] = omega + alpha * ((Y[t-1] - mu) ** 2) + beta * (sigma2[t-1])
        F[t] = Y[t] - mu - np.sqrt(sigma2[t]) * np.random.normal(0, 1, 1)
        v[t] = sigma2[t]
        GARCH_Dens[t] = (1 / 2) * np.log(2 * np.pi) + (1 / 2) * np.log(v[t]) + (1 / 2) * (F[t] / v[t])
        Likelihood += GARCH_Dens[t]  
    
    return Likelihood

# %%
def garch_path(params, *args):
    mu = params[0]
    omega = params[1]
    alpha = params[2]
    beta = params[3]
    sigma2, path = {}, {}
    # initialize volatility and path
    sigma2[0] = np.var(Y)
    path[0] = np.array([Y[0]])
    for t in range(1, T):
        sigma2[t] = omega + alpha * ((Y[t-1] - mu) ** 2) + beta * (sigma2[t-1])
        path[t] = mu + np.sqrt(sigma2[t]) * np.random.normal(0, 1, 1)    
        
    return path, sigma2

# %%
#GARCH model to forecast stock return
Y = np.diff(np.log(stock['Adj Close'].values))
T = Y.shape[0]

#param0 = np.array([np.mean(Y), np.var(Y) / 900, 0.18, 0.001])
#param0 = np.array([np.mean(Y), np.var(Y) / 500, 0.2, 0.001])
param0 = np.array([np.mean(Y), np.var(Y) / 400, 0.1, 0.03])
results = minimize(garch, param0, method='BFGS', tol=1e-2, options={'disp': True})
param_star = results.x

path, vol = garch_path(param_star, Y, T)
Y_GARCH = path.values()

timevec = np.linspace(1, T, T)
plt.plot(timevec, Y, 'b', timevec, Y_GARCH, 'r')
plt.xlabel('Time')
plt.ylabel('Log Returns')
plt.title('GARCH Model Prediction vs Actual Log Returns (Tesla)')
plt.legend(['Actual Returns', 'GARCH Predicted Returns'])
plt.show()

# Extracting the dictionary values into a list (in the same order as keys)
GARCH_prediction = list(Y_GARCH)

# Calculate RMSE
RMSE = np.sqrt(np.mean((np.array(GARCH_prediction) - np.array(Y)) ** 2))
print(f'RMSE value is: {RMSE}%')
# Out:
#          Current function value: -21319.667896
#          Iterations: 1
#          Function evaluations: 111
#          Gradient evaluations: 20
# /Users/sahanajprakash/Repos/python-data/env/lib/python3.12/site-packages/scipy/optimize/_minimize.py:708: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
# RMSE value is: 0.044346794181923506%

# %% [markdown]
# ## Kalman Filter

# %%
#Kalman filter code to predict Tesla's daily stock prices
import numpy as np
import pandas as pd
from scipy.optimize import minimize
from pandas_datareader import DataReader
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

stock_symbol = 'TSLA'

# Download stock data
stock = yf.download(stock_symbol, start_date, end_date)
def kalman_filter(param, *args):
    # initialize params
    Z = param[0]
    T = param[1]
    H = param[2]
    Q = param[3]
    # initialize vector values:
    u_predict, u_update, P_predict, P_update, v, F = {}, {}, {}, {}, {}, {}
    Y, S = args
    u_update[0] = Y[0]
    u_predict[0] = u_update[0]
    P_update[0] = np.var(Y) / 4
    P_predict[0] = T * P_update[0] * np.transpose(T) + Q
    Likelihood = 0
    for s in range(1, S):
        F[s] = Z * P_predict[s - 1] * np.transpose(Z) + H
        v[s] = Y[s - 1] - Z * u_predict[s - 1]
        u_update[s] = u_predict[s - 1] + P_predict[s - 1] * np.transpose(Z) * (1 / F[s]) * v[s]
        u_predict[s] = T * u_update[s]
        P_update[s] = P_predict[s - 1] - P_predict[s - 1] * np.transpose(Z) * (1 / F[s]) * Z * P_predict[s - 1]
        P_predict[s] = T * P_update[s] * np.transpose(T) + Q
        Likelihood += (1 / 2) * np.log(2 * np.pi) + (1 / 2) * np.log(abs(F[s])) + (1 / 2) * np.transpose(v[s]) * (1 / F[s]) * v[s]

    return Likelihood

def kalman_smoother(params, *args):
    # initialize params
    Z = params[0]
    T = params[1]
    H = params[2]
    Q = params[3]
    # initialize vector values:
    u_predict, u_update, P_predict, P_update, v, F = {}, {}, {}, {}, {}, {}
    Y, S = args
    u_update[0] = Y[0]
    u_predict[0] = u_update[0]
    P_update[0] = np.var(Y) / 4
    P_predict[0] = T * P_update[0] * np.transpose(T) + Q
    for s in range(1, S):
        F[s] = Z * P_predict[s - 1] * np.transpose(Z) + H
        v[s] = Y[s - 1] - Z * u_predict[s - 1]
        u_update[s] = u_predict[s - 1] + P_predict[s - 1] * np.transpose(Z) * (1 / F[s]) * v[s]
        u_predict[s] = T * u_update[s]
        P_update[s] = P_predict[s - 1] - P_predict[s - 1] * np.transpose(Z) * (1 / F[s]) * Z * P_predict[s - 1]
        P_predict[s] = T * P_update[s] * np.transpose(T) + Q

    u_smooth, P_smooth = {}, {}
    u_smooth[S - 1] = u_update[S - 1]
    P_smooth[S - 1] = P_update[S - 1]
    for t in range(S - 1, 0, -1):
        u_smooth[t - 1] = u_update[t] + P_update[t] * np.transpose(T) / P_predict[t] * (u_smooth[t] - T * u_update[t])
        P_smooth[t - 1] = P_update[t] + P_update[t] * np.transpose(T) / P_predict[t] * (P_smooth[t] - P_predict[t]) / P_predict[t] * T * P_update[t]

    smooth_path = u_smooth
    return smooth_path

Y = stock['Adj Close'].values
S = Y.shape[0]

# Initial parameters
param0 = np.array([0.24, 4.25, np.var(Y) / 2000, np.var(Y) / 50])
results = minimize(kalman_filter, param0, args=(Y, S), method='BFGS', tol=1e-2, options={'disp': True})

# Smoothe and visualize the estimated path
param_star = results.x
path = kalman_smoother(param_star, Y, S)
sorted_path = dict(sorted(path.items()))
Y_kalmanFilter = sorted_path.values()

# Plotting results
timevec = np.linspace(1, S, S)
plt.title('Kalman Filter Stock Price Prediction: ' + stock_symbol)
plt.plot(timevec, Y_kalmanFilter, 'r', label='Kalman Filter Prediction')
plt.plot(timevec, Y, 'b:', label='Actual Stock Price')
plt.legend()
plt.show()

# Extracting the dictionary values into a list (in the same order as keys)
kalman_values = list(Y_kalmanFilter)

# Calculate RMSE
RMSE = np.sqrt(np.mean((np.array(kalman_values) - np.array(Y)) ** 2))
print('RMSE value is: $', RMSE)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Optimization terminated successfully.
#          Current function value: 4097.014116
#          Iterations: 150
#          Function evaluations: 1095
#          Gradient evaluations: 219
# RMSE value is: $ 0.8600117511381193

# %% [markdown]
# ## SMA and EMA

# %%
# Define the date range and stock symbol
start_date = '2020-01-01'
end_date = '2024-08-31'
stock_symbol = 'TSLA'

# Load the Tesla stock data using yfinance
stock_data = yf.download(stock_symbol, start=start_date, end=end_date)

# Display the first few rows of data
print(stock_data.head())

# Calculate Simple Moving Averages (SMA)
stock_data['SMA_20'] = stock_data['Close'].rolling(window=20).mean()
stock_data['SMA_50'] = stock_data['Close'].rolling(window=50).mean()

# Calculate Exponential Moving Averages (EMA)
stock_data['EMA_20'] = stock_data['Close'].ewm(span=20, adjust=False).mean()
stock_data['EMA_50'] = stock_data['Close'].ewm(span=50, adjust=False).mean()

# Plot the closing price along with SMAs and EMAs
plt.figure(figsize=(14,7))
plt.plot(stock_data.index, stock_data['Close'], label='Closing Price', color='blue')
plt.plot(stock_data.index, stock_data['SMA_20'], label='20-day SMA', color='red', linestyle='--')
plt.plot(stock_data.index, stock_data['SMA_50'], label='50-day SMA', color='green', linestyle='--')
plt.plot(stock_data.index, stock_data['EMA_20'], label='20-day EMA', color='orange', linestyle='-.')
plt.plot(stock_data.index, stock_data['EMA_50'], label='50-day EMA', color='purple', linestyle='-.')

plt.title('Tesla Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# Identify Golden Cross and Death Cross
# Golden Cross: when short-term SMA crosses above long-term SMA
golden_cross = stock_data[(stock_data['SMA_20'] > stock_data['SMA_50']) & (stock_data['SMA_20'].shift(1) <= stock_data['SMA_50'].shift(1))]

# Death Cross: when short-term SMA crosses below long-term SMA
death_cross = stock_data[(stock_data['SMA_20'] < stock_data['SMA_50']) & (stock_data['SMA_20'].shift(1) >= stock_data['SMA_50'].shift(1))]

# Plot the crossovers on the price chart
plt.figure(figsize=(14,7))
plt.plot(stock_data.index, stock_data['Close'], label='Closing Price', color='blue')
plt.plot(stock_data.index, stock_data['SMA_20'], label='20-day SMA', color='red', linestyle='--')
plt.plot(stock_data.index, stock_data['SMA_50'], label='50-day SMA', color='green', linestyle='--')

# Mark Golden Cross points
plt.scatter(golden_cross.index, stock_data.loc[golden_cross.index, 'Close'], marker='^', color='green', label='Golden Cross', s=100)

# Mark Death Cross points
plt.scatter(death_cross.index, stock_data.loc[death_cross.index, 'Close'], marker='v', color='red', label='Death Cross', s=100)

plt.title('Tesla Stock Price with SMA Crossovers')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500

# %% [markdown]
# ## RSI

# %%
# Step 1: Calculate daily price changes
stock_data['Change'] = stock_data['Close'].diff()

# Step 2: Calculate gains and losses
stock_data['Gain'] = np.where(stock_data['Change'] > 0, stock_data['Change'], 0)
stock_data['Loss'] = np.where(stock_data['Change'] < 0, -stock_data['Change'], 0)

# Step 3: Calculate the 14-day rolling average gain and loss
window_length = 14
stock_data['Avg_Gain'] = stock_data['Gain'].rolling(window=window_length).mean()
stock_data['Avg_Loss'] = stock_data['Loss'].rolling(window=window_length).mean()

# Step 4: Calculate the Relative Strength (RS)
stock_data['RS'] = stock_data['Avg_Gain'] / stock_data['Avg_Loss']

# Step 5: Calculate the RSI
stock_data['RSI'] = 100 - (100 / (1 + stock_data['RS']))

# Step 6: Plotting the RSI
plt.figure(figsize=(12, 6))
plt.plot(stock_data['RSI'], label='RSI')
plt.axhline(70, color='red', linestyle='--', label='Overbought (70)')
plt.axhline(30, color='blue', linestyle='--', label='Oversold (30)')
plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend()
plt.show()

# %%
# !pip install ta
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=c8f3f2047dd9165ea5cc2e1bde1923c653e7bca6864e600093c683c1fe8349cb
#   Stored in directory: /Users/sahanajprakash/Library/Caches/pip/wheels/5c/a1/5f/c6b85a7d9452057be4ce68a8e45d77ba34234a6d46581777c6
# Successfully built ta
# ...

# %% [markdown]
# ## On Balance Volume

# %%
from ta.volume import OnBalanceVolumeIndicator

# initialize OBV
close = stock['Close'].squeeze()
volume = stock['Volume'].squeeze()
obv_indicator = OnBalanceVolumeIndicator(close=close, volume=volume)

# calculate OBV
stock['OBV'] = obv_indicator.on_balance_volume()

# %%
# Visualization

# plt.figure(figsize=(14,7))

# # plot Close
# plt.subplot(2, 1, 1)
# plt.plot(stock.index, stock['Close'], label='Close Price', color='blue')
# plt.title('TSLA Close Price and OBV')
# plt.xlabel('Date')
# plt.ylabel('Close Price')
# plt.legend()

# # plot OBV
# plt.subplot(2, 1, 2)
# plt.plot(stock.index, stock['OBV'], label='On-Balance Volume (OBV)', color='orange')
# plt.xlabel('Date')
# plt.ylabel('OBV')
# plt.legend()

# plt.tight_layout()
# plt.show()

fig, ax1 = plt.subplots(figsize=(14,7))

#plot Close
color = 'tab:blue'
ax1.set_xlabel('Date')
ax1.set_ylabel('Close Price', color=color)
ax1.plot(stock.index, stock['Close'], label='Close Price', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Second Y axis
ax2 = ax1.twinx()
color = 'tab:orange'
ax2.set_ylabel('OBV', color=color)
ax2.plot(stock.index, stock['OBV'], label='On-Balance Volume (OBV)', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Combine legends
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper left')

plt.title('TSLA Close Price and On-Balance Volume (OBV)')
plt.show()

# %% [markdown]
# ## Candlestick

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots


stock_symbol = 'TSLA'

# Download stock data
stock = yf.download(stock_symbol, start_date, end_date)

# Create a subplot with 2 rows, sharing the x-axis
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
                    row_heights=[0.8, 0.2], # Adjusting heights for price and volume
                    vertical_spacing=0.03)

# Add the candlestick chart to the first row
fig.add_trace(go.Candlestick(x=stock.index,
                             open=stock['Open'],
                             high=stock['High'],
                             low=stock['Low'],
                             close=stock['Close'],
                             name='Price'), 
              row=1, col=1)

# Add the volume bar chart to the second row
fig.add_trace(go.Bar(x=stock.index, 
                     y=stock['Volume'], 
                     name='Volume', 
                     marker=dict(color='blue')), 
              row=2, col=1)

# Update layout for the figure
fig.update_layout(
    title=stock_symbol + " Stock Price and Volume",
    yaxis_title='Price (USD)',
    yaxis2_title='Volume',
    xaxis_rangeslider_visible=False,
    height=800
)

fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
